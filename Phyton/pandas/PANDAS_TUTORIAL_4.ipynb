# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonanda1013/My-Swords/blob/main/Phyton/pandas/PANDAS_TUTORIAL_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> PANDAS SERIES dan DATAFRAME

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h2> > Perbedaan Array Numpay dan Series Pandas

# %%
angka = [1,2,3]
label = ['sayu', 'dua', 'tiga']
np_array = np.array(angka)
np_array
# Out:
# array([1, 2, 3])

# %% [markdown]
# <h3> >> pandas series

# %%
d = {'a':1,'b':2,'c':3}
pd_series = pd.Series(data = angka, index = label)
pd_series_d=pd.Series(d)
print(pd_series)
print(pd_series_d)
# Out:
# sayu    1
# dua     2
# tiga    3
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd_series_d.to_frame()
# Out:
#    0
# a  1
# b  2
# c  3

# %% [markdown]
# <h2> DATAFRAME

# %%
dataku = pd.DataFrame(np.random.randn(), index = 'A B C D E'.split(), columns = 'W X Y Z'.split())

# %%
dataku
# Out:
#           W         X         Y         Z
# A  0.001728  0.001728  0.001728  0.001728
# B  0.001728  0.001728  0.001728  0.001728
# C  0.001728  0.001728  0.001728  0.001728
# D  0.001728  0.001728  0.001728  0.001728
# E  0.001728  0.001728  0.001728  0.001728

# %%
dataku['baru'] = dataku['Y'] + dataku['X']
dataku
# Out:
#           W         X         Y         Z      baru
# A  0.001728  0.001728  0.001728  0.001728  0.003456
# B  0.001728  0.001728  0.001728  0.001728  0.003456
# C  0.001728  0.001728  0.001728  0.001728  0.003456
# D  0.001728  0.001728  0.001728  0.001728  0.003456
# E  0.001728  0.001728  0.001728  0.001728  0.003456

# %%
dataku.drop('W',axis=1)
# Out:
#           X         Y         Z      baru
# A  0.001728  0.001728  0.001728  0.003456
# B  0.001728  0.001728  0.001728  0.003456
# C  0.001728  0.001728  0.001728  0.003456
# D  0.001728  0.001728  0.001728  0.003456
# E  0.001728  0.001728  0.001728  0.003456
